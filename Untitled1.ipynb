# %%
import pandas as pd
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# %%
orig_data=pd.read_csv('directory.csv')

# %%
plt.scatter(orig_data['Longitude'], orig_data['Latitude'], marker='*', color="blue")
plt.title('Starbucks stores by location')
# Out:
# Text(0.5,1,'Starbucks stores by location')
